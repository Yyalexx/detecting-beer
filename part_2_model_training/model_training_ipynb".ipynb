# %% [markdown]
# <a href="https://colab.research.google.com/github/Yyalexx/detecting-beer/blob/master/model_training_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os 
import shutil 
import glob 
from tqdm import tqdm
from PIL import Image
from sklearn.model_selection import train_test_split
import torch

# %% [markdown]
# # Обработка данных

# %%
# Задаем все пути к файлам и создаем папки для последующей работы с подсчетом метрик

# Корневая папка
path_to_files = "/content/gdrive/MyDrive/VIZIT/YOLO5"

# Исходные файлы изображений и labels
path_to_images = os.path.join(path_to_files, 'all_images_4_YOLO5/')
path_to_labels = os.path.join(path_to_files, 'all_labels_4_YOLO5/')

# Преобразованные файлы изображений и labels
path_to_resized_images = os.path.join(path_to_files, 'resized_images/')
path_to_resized_labels = os.path.join(path_to_files, 'resized_labels/')

# Если папок не существует, создаем их
if not os.path.exists(path_to_resized_images):
  os.mkdir(path_to_resized_images)
if not os.path.exists(path_to_resized_labels):
  os.mkdir(path_to_resized_labels)

# %%
# Функция для изменения размеров изображения и переноса изображения и labels в папку resized
def scale_image_label(input_image_path,
                      width=640,
                      height=640, 
                      path_to_files=path_to_files,
                      path_to_resized_images=path_to_resized_images,
                      path_to_resized_labels=path_to_resized_labels
                      ):
    """
    Функция приводит изображение к размеру width X height, 
    производит поворот изображения в соответствии с exif данными.

      Args:
        input_image_path (string): путь к изображению
        width (int) = ширина обработанного изображения
        height (int) = высота обработанного изображения
                                            
      Returns:
        None(None)
    """
    original_image = Image.open(input_image_path)
    resized_image = original_image.resize((width, height), Image.LANCZOS)
    if hasattr(original_image, '_getexif') or original_image._getexif() is not None:
        orientation = original_image._getexif().get(0x112)
        rotate_values = {3: 180, 6: 270, 8: 90}
        if orientation in rotate_values:
            img = resized_image.rotate(rotate_values[orientation])
        else:
            img = resized_image    
 
    img.save(os.path.join(path_to_resized_images, input_image_path.split('/')[-1]))

    label_name = input_image_path.split('/')[-1][:-3]+'txt'
    input_label_path = os.path.join(path_to_files, 'all_labels_4_YOLO5/', label_name)
    shutil.copy(input_label_path, path_to_resized_labels)

# %%
# Обрабатываем все исходные изображения
for img_name in tqdm(glob.glob(os.path.join(path_to_images, '*.jpg'))):
    scale_image_label(img_name)
# Out:
# 100%|██████████| 530/530 [04:20<00:00,  2.04it/s]

# %%
# Деление тренировочных данных на train, val, test
rnd_seed = 123
all_imgs_pathes = sorted(glob.glob(os.path.join(path_to_resized_images, '*.jpg')))
all_lbls_pathes = sorted(glob.glob(os.path.join(path_to_resized_labels, '*.txt')))
indices = list(range(len(all_imgs_pathes)))

df_train_inds, df_val_test_inds = train_test_split(indices, test_size=0.1, 
                                                   random_state=rnd_seed)
df_val_inds, df_test_inds = train_test_split(df_val_test_inds, test_size=0.5, 
                                             random_state=rnd_seed)

# %%
print(f'Размеры выборок:\ntrain - {len(df_train_inds)}\nval - {len(df_val_inds)}\ntest - {len(df_test_inds)}')
# Out:
# Размеры выборок:
# train - 477
# val - 26
# test - 27

# %%
# Создаем папки для переноса данных по папкам train, valid, test (структура для YOLOv5)
train_imgs_path = os.path.join(path_to_files, 'dataset', 'images', 'train')
train_lbls_path = os.path.join(path_to_files, 'dataset', 'labels', 'train')
if os.path.exists(train_imgs_path):
    shutil.rmtree(train_imgs_path)
os.makedirs(train_imgs_path)
if os.path.exists(train_lbls_path):
    shutil.rmtree(train_lbls_path)
os.makedirs(train_lbls_path)

valid_imgs_path = os.path.join(path_to_files, 'dataset', 'images', 'valid')
valid_lbls_path = os.path.join(path_to_files, 'dataset', 'labels', 'valid')
if os.path.exists(valid_imgs_path):
    shutil.rmtree(valid_imgs_path)
os.makedirs(valid_imgs_path)
if os.path.exists(valid_lbls_path):
    shutil.rmtree(valid_lbls_path)
os.makedirs(valid_lbls_path)

test_imgs_path = os.path.join(path_to_files, 'dataset', 'images', 'test')
test_lbls_path = os.path.join(path_to_files, 'dataset', 'labels', 'test')
if os.path.exists(test_imgs_path):
    shutil.rmtree(test_imgs_path)
os.makedirs(test_imgs_path)
if os.path.exists(test_lbls_path):
    shutil.rmtree(test_lbls_path)
os.makedirs(test_lbls_path)

# %%
# Перемещение файлов из папки resized в train, valid, test
for train_ind in df_train_inds:
    shutil.move(all_imgs_pathes[train_ind], train_imgs_path)
    shutil.move(all_lbls_pathes[train_ind], train_lbls_path)

for valid_ind in df_val_inds:
    shutil.move(all_imgs_pathes[valid_ind], valid_imgs_path)
    shutil.move(all_lbls_pathes[valid_ind], valid_lbls_path)

for test_ind in df_test_inds:
    shutil.move(all_imgs_pathes[test_ind], test_imgs_path)
    shutil.move(all_lbls_pathes[test_ind], test_lbls_path)

# %% [markdown]
# # Обучение модели

# %%
#Клонируем репозиторий YOLOv5 и устанавливаем зависимости
# !git clone https://github.com/ultralytics/yolov5 
# %cd yolov5
# %pip install -qr requirements.txt

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14983, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 14983 (delta 19), reused 21 (delta 8), pack-reused 14936
# Receiving objects: 100% (14983/14983), 13.97 MiB | 28.72 MiB/s, done.
# Resolving deltas: 100% (10283/10283), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 39.1 MB/s eta 0:00:00
# Setup complete. Using torch 1.13.0+cu116 (Tesla T4)

# %%
# Обучение модели
# !python train.py --img 640 --cfg yolov5m.yaml --batch 32 --epochs 300 --data /content/gdrive/MyDrive/VIZIT/YOLO5/dataset/data.yaml --weights yolov5m.pt --cache --workers 2
# Out:
# train: weights=yolov5m.pt, cfg=yolov5m.yaml, data=/content/gdrive/MyDrive/VIZIT/YOLO5/dataset/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-66-g9650f16 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 17.0MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m.pt to yolov5m.pt...
# 100% 40.8M/40.8M [00:00<00:00, 74.8MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# YOLOv5m summary: 291 layers, 20871318 parameters, 20871318 gradients, 48.2 GFLOPs
#
# Transferred 474/481 items from yolov5m.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.0005), 82 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/gdrive/MyDrive/VIZIT/YOLO5/dataset/labels/train.cache... 477 images, 226 backgrounds, 0 corrupt: 100% 477/477 [00:00<?, ?it/s]
# train: Caching images (0.5GB ram): 100% 477/477 [00:03<00:00, 130.48it/s]
# val: Scanning /content/gdrive/MyDrive/VIZIT/YOLO5/dataset/labels/valid.cache... 26 images, 11 backgrounds, 0 corrupt: 100% 26/26 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100% 26/26 [00:00<00:00, 34.53it/s]
#
# AutoAnchor: 5.26 anchors/target, 0.996 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299      12.1G     0.1092    0.02635          0         76        640: 100% 15/15 [00:15<00:00,  1.02s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.70s/it]
#                    all         26         51   0.000128     0.0196   7.74e-05   7.74e-06
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299      12.1G    0.09209    0.02742          0         77        640: 100% 15/15 [00:11<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.58it/s]
#                    all         26         51    0.00128      0.196   0.000812   0.000283
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299      12.1G    0.07843     0.0269          0         57        640: 100% 15/15 [00:11<00:00,  1.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.70it/s]
#                    all         26         51     0.0181      0.882      0.208     0.0969
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299      12.1G    0.07041    0.02326          0         31        640: 100% 15/15 [00:11<00:00,  1.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.91it/s]
#                    all         26         51      0.248      0.412      0.201     0.0591
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299      12.1G    0.06789    0.02279          0         78        640: 100% 15/15 [00:11<00:00,  1.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.92it/s]
#                    all         26         51      0.401      0.647      0.426      0.173
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299      12.1G    0.06338    0.02101          0         72        640: 100% 15/15 [00:11<00:00,  1.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.12it/s]
#                    all         26         51       0.73      0.582      0.683      0.425
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299      12.1G    0.06158    0.01826          0         82        640: 100% 15/15 [00:11<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.09it/s]
#                    all         26         51      0.654       0.49      0.629       0.18
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299      12.1G    0.06017    0.01483          0         82        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.12it/s]
#                    all         26         51      0.734      0.706      0.841      0.431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299      12.1G    0.06002     0.0131          0         71        640: 100% 15/15 [00:11<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51       0.85      0.745      0.843      0.253
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299      12.1G    0.05552    0.01089          0         53        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.21it/s]
#                    all         26         51      0.865       0.88      0.935      0.567
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299      12.1G    0.05356    0.01019          0         66        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.13it/s]
#                    all         26         51      0.919      0.902      0.956       0.57
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299      12.1G    0.05144   0.009982          0         57        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.25it/s]
#                    all         26         51      0.743      0.941       0.92      0.443
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299      12.1G    0.04969   0.009628          0         63        640: 100% 15/15 [00:11<00:00,  1.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.894      0.804      0.928      0.579
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299      12.1G    0.04961   0.009646          0         66        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.74it/s]
#                    all         26         51      0.914      0.922       0.95      0.547
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299      12.1G    0.04781   0.009857          0         79        640: 100% 15/15 [00:11<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51      0.918      0.941      0.961       0.55
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299      12.1G    0.04638    0.00862          0         55        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.942      0.956      0.966      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299      12.1G    0.04614   0.008781          0         79        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51      0.922       0.98      0.966      0.546
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/299      12.1G     0.0455   0.008433          0         53        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.22it/s]
#                    all         26         51      0.943       0.98      0.971       0.65
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/299      12.1G    0.04623   0.008102          0         70        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.934      0.922      0.958       0.65
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/299      12.1G    0.04504   0.007927          0         84        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.926      0.978       0.95      0.557
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/299      12.1G    0.04415   0.007708          0         57        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.12it/s]
#                    all         26         51      0.908       0.98      0.946      0.659
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/299      12.1G    0.04272   0.008358          0         65        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         26         51      0.943       0.98      0.959      0.675
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/299      12.1G    0.04292   0.007256          0         60        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.17it/s]
#                    all         26         51      0.922       0.98      0.943      0.617
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/299      12.1G    0.04299   0.007561          0         66        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51       0.96      0.961      0.976      0.686
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/299      12.1G    0.04089   0.007837          0         50        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.955       0.98      0.983      0.636
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/299      12.1G    0.04101   0.007593          0         85        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.998       0.98       0.99      0.683
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/299      12.1G    0.03976   0.006861          0         74        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.17it/s]
#                    all         26         51      0.964      0.941       0.98      0.632
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/299      12.1G    0.04216   0.007289          0         67        640: 100% 15/15 [00:11<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.72it/s]
#                    all         26         51      0.976      0.922      0.968      0.661
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/299      12.1G    0.04123   0.007862          0         83        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51      0.964      0.863      0.947      0.685
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/299      12.1G     0.0411   0.007075          0         77        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.23it/s]
#                    all         26         51      0.951      0.843      0.903      0.605
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/299      12.1G    0.04156    0.00692          0         75        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.13it/s]
#                    all         26         51       0.94      0.924      0.972      0.691
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/299      12.1G    0.03853   0.006733          0         80        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.942      0.958      0.982      0.699
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/299      12.1G    0.03971   0.006611          0         83        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.16it/s]
#                    all         26         51      0.985      0.902      0.982      0.668
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/299      12.1G    0.04092   0.006896          0         79        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.18it/s]
#                    all         26         51      0.938       0.89      0.978      0.727
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/299      12.1G    0.04036   0.007314          0         62        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.13it/s]
#                    all         26         51       0.96      0.939       0.97        0.6
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/299      12.1G    0.04045    0.00784          0         53        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.21it/s]
#                    all         26         51      0.979      0.928      0.987      0.703
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/299      12.1G    0.03888   0.006728          0         72        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51      0.994      0.863      0.974       0.71
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/299      12.1G    0.03797   0.007292          0         79        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.30it/s]
#                    all         26         51      0.997      0.922      0.988      0.656
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/299      12.1G    0.03846     0.0066          0         54        640: 100% 15/15 [00:11<00:00,  1.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.20it/s]
#                    all         26         51       0.94      0.914       0.97      0.714
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/299      12.1G    0.03982   0.006564          0         65        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.17it/s]
#                    all         26         51      0.945      0.941      0.983      0.707
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/299      12.1G    0.03788   0.006525          0         70        640: 100% 15/15 [00:11<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.27it/s]
#                    all         26         51       0.92      0.902      0.973      0.679
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/299      12.1G    0.04065   0.006887          0         72        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.27it/s]
#                    all         26         51       0.95      0.902      0.969      0.684
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/299      12.1G    0.03677   0.006418          0         67        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.23it/s]
#                    all         26         51      0.955      0.922      0.959      0.711
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/299      12.1G    0.03935   0.006945          0         61        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.23it/s]
#                    all         26         51      0.955       0.84      0.935      0.684
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/299      12.1G    0.03734   0.007016          0         70        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.21it/s]
#                    all         26         51      0.955      0.941      0.967      0.695
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/299      12.1G     0.0361   0.006838          0         82        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.17it/s]
#                    all         26         51      0.958      0.899      0.971      0.726
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/299      12.1G    0.03643   0.006278          0         97        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.14it/s]
#                    all         26         51      0.956      0.902      0.977      0.729
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/299      12.1G    0.03868   0.006951          0         91        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.22it/s]
#                    all         26         51      0.943      0.975      0.988      0.724
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/299      12.1G    0.03434   0.006366          0         62        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.13it/s]
#                    all         26         51      0.961      0.974      0.988       0.74
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/299      12.1G    0.03561   0.006423          0         77        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.12it/s]
#                    all         26         51      0.958       0.89      0.971      0.641
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/299      12.1G    0.03734    0.00674          0         99        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51      0.992      0.843       0.94      0.678
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/299      12.1G    0.03563   0.006263          0         71        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.20it/s]
#                    all         26         51      0.973      0.843      0.944      0.696
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/299      12.1G    0.03675   0.006058          0         62        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.11it/s]
#                    all         26         51      0.942      0.922      0.969       0.73
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/299      12.1G    0.03568   0.006561          0         86        640: 100% 15/15 [00:11<00:00,  1.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.95it/s]
#                    all         26         51      0.961      0.978      0.985      0.771
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/299      12.1G    0.03591    0.00623          0         65        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.921      0.911      0.961      0.713
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/299      12.1G    0.03565   0.006245          0         62        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.25it/s]
#                    all         26         51       0.94      0.922      0.975      0.677
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/299      12.1G    0.03722   0.006435          0         71        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.935      0.941      0.953      0.696
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/299      12.1G    0.03514   0.005943          0         66        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.939       0.98      0.968      0.718
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/299      12.1G    0.03636   0.006521          0         82        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.14it/s]
#                    all         26         51      0.957       0.98      0.973      0.714
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/299      12.1G    0.03578   0.006062          0        101        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.27it/s]
#                    all         26         51      0.957      0.941      0.975      0.697
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/299      12.1G    0.03545   0.005998          0         69        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.21it/s]
#                    all         26         51      0.957      0.922      0.962       0.72
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/299      12.1G    0.03559   0.006145          0         52        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51       0.95      0.863      0.934      0.698
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/299      12.1G    0.03479   0.006685          0         84        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.929      0.843      0.864      0.645
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/299      12.1G    0.03711   0.005645          0         55        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.21it/s]
#                    all         26         51      0.955      0.863      0.896      0.675
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/299      12.1G    0.03427    0.00637          0         64        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.18it/s]
#                    all         26         51      0.953      0.795      0.943      0.688
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/299      12.1G    0.03403   0.006185          0         46        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.31it/s]
#                    all         26         51      0.954      0.922      0.973      0.733
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/299      12.1G    0.03471   0.006067          0         83        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.42it/s]
#                    all         26         51      0.961       0.96      0.971       0.69
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/299      12.1G    0.03338   0.005629          0         65        640: 100% 15/15 [00:11<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         26         51      0.955      0.961      0.969       0.66
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/299      12.1G    0.03298    0.00558          0         52        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.11it/s]
#                    all         26         51      0.955      0.961      0.956      0.697
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/299      12.1G    0.03286   0.005913          0         87        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.958      0.901       0.97      0.695
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/299      12.1G    0.03393   0.005762          0         79        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.14it/s]
#                    all         26         51      0.983      0.941      0.988      0.719
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/299      12.1G      0.033    0.00589          0         76        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.959      0.961      0.978      0.762
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/299      12.1G    0.03404   0.006143          0         53        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.917      0.922      0.958      0.745
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/299      12.1G    0.03305   0.005805          0         45        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.13it/s]
#                    all         26         51      0.903      0.922      0.965      0.746
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/299      12.1G    0.03595   0.005443          0         59        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.20it/s]
#                    all         26         51      0.939      0.843      0.916      0.715
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/299      12.1G    0.03438   0.005557          0         46        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.939      0.961      0.969      0.726
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/299      12.1G    0.03408   0.006202          0         75        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51       0.94      0.917      0.972      0.719
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/299      12.1G    0.03426   0.005828          0         74        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.13it/s]
#                    all         26         51      0.959      0.912      0.982      0.721
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/299      12.1G    0.03456   0.005136          0         81        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.958      0.902      0.968      0.723
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/299      12.1G    0.03189   0.005688          0         57        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.928      0.882      0.958      0.723
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/299      12.1G    0.03205   0.006018          0         53        640: 100% 15/15 [00:11<00:00,  1.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51      0.962       0.98      0.988      0.767
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/299      12.1G     0.0335   0.006699          0         51        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.16it/s]
#                    all         26         51      0.961      0.959      0.981      0.767
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/299      12.1G    0.03349   0.005967          0         52        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51      0.957      0.869      0.959      0.734
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/299      12.1G    0.03315   0.005732          0         81        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.30it/s]
#                    all         26         51      0.952      0.843      0.943       0.72
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/299      12.1G    0.03258   0.005807          0         57        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.956      0.857      0.918      0.694
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/299      12.1G    0.03315   0.005918          0         47        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         26         51      0.958      0.904      0.958      0.744
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/299      12.1G    0.03408   0.005485          0         63        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.958      0.898      0.977      0.741
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/299      12.1G    0.03374   0.005948          0         66        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         26         51      0.961       0.98      0.972      0.676
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/299      12.1G    0.03327   0.005213          0         68        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51      0.961      0.958      0.959      0.721
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/299      12.1G    0.03205   0.005781          0         74        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.25it/s]
#                    all         26         51       0.96       0.98      0.985      0.754
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/299      12.1G     0.0311   0.005624          0         67        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.961      0.972      0.988      0.759
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/299      12.1G     0.0325   0.005482          0         55        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.994      0.882      0.973      0.752
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/299      12.1G    0.03266   0.005464          0         68        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.18it/s]
#                    all         26         51      0.981      0.941      0.983      0.752
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/299      12.1G    0.03308    0.00552          0         75        640: 100% 15/15 [00:11<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         26         51      0.959      0.925       0.98      0.776
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/299      12.1G    0.03462   0.005462          0         70        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.18it/s]
#                    all         26         51       0.96       0.93      0.978      0.778
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/299      12.1G    0.03378   0.005809          0         57        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.12it/s]
#                    all         26         51      0.958        0.9      0.964      0.739
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/299      12.1G     0.0332   0.005647          0         75        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.17it/s]
#                    all         26         51      0.956       0.86      0.952      0.734
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/299      12.1G    0.03172   0.005389          0         68        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.28it/s]
#                    all         26         51       0.96      0.934      0.978      0.758
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/299      12.1G     0.0316   0.005777          0         73        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.20it/s]
#                    all         26         51       0.98      0.951      0.987      0.752
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/299      12.1G    0.03211   0.005403          0         63        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.18it/s]
#                    all         26         51      0.974       0.98      0.993      0.761
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/299      12.1G    0.03163   0.005421          0         53        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         26         51      0.978      0.876      0.958      0.643
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/299      12.1G    0.03163    0.00506          0         62        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.952      0.843       0.95      0.732
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     102/299      12.1G    0.03098   0.005613          0         78        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.18it/s]
#                    all         26         51      0.956      0.859       0.95       0.73
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     103/299      12.1G    0.03288    0.00587          0         73        640: 100% 15/15 [00:11<00:00,  1.29it/s]
# ...
#     262/299      12.1G    0.02499   0.003712          0         72        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.23it/s]
#                    all         26         51       0.96       0.93      0.978      0.813
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     263/299      12.1G    0.02475   0.003603          0         77        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.27it/s]
#                    all         26         51      0.959      0.921      0.977      0.809
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     264/299      12.1G     0.0258   0.003858          0         63        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.22it/s]
#                    all         26         51      0.959      0.917      0.976      0.817
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     265/299      12.1G    0.02427   0.003582          0         48        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         26         51      0.955      0.902      0.969        0.8
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     266/299      12.1G    0.02453    0.00374          0         66        640: 100% 15/15 [00:12<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.20it/s]
#                    all         26         51       0.94      0.917      0.971      0.803
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     267/299      12.1G    0.02293    0.00321          0         64        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.33it/s]
#                    all         26         51      0.958      0.922      0.982      0.814
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     268/299      12.1G    0.02345   0.003152          0         66        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.18it/s]
#                    all         26         51      0.959      0.919      0.982      0.818
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     269/299      12.1G     0.0266    0.00367          0         51        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.31it/s]
#                    all         26         51      0.959       0.92      0.984      0.817
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     270/299      12.1G    0.02442   0.003506          0         64        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.21it/s]
#                    all         26         51      0.953      0.902      0.974      0.806
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     271/299      12.1G    0.02431   0.003425          0         52        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.37it/s]
#                    all         26         51      0.951      0.902      0.966      0.806
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     272/299      12.1G    0.02383   0.003487          0         73        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.32it/s]
#                    all         26         51      0.954      0.902      0.965      0.795
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     273/299      12.1G    0.02475   0.003406          0         44        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.32it/s]
#                    all         26         51      0.956      0.902      0.968      0.813
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     274/299      12.1G    0.02387   0.003532          0         74        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.953      0.902      0.977      0.817
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     275/299      12.1G     0.0235   0.003468          0         51        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all         26         51      0.951       0.98      0.989      0.834
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     276/299      12.1G     0.0238   0.003321          0         60        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.25it/s]
#                    all         26         51      0.959          1      0.989      0.835
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     277/299      12.1G    0.02731   0.003618          0         83        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         26         51      0.956          1      0.988      0.829
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     278/299      12.1G    0.02363   0.003227          0         55        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.21it/s]
#                    all         26         51      0.961      0.978      0.987      0.825
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     279/299      12.1G    0.02515   0.003578          0         64        640: 100% 15/15 [00:12<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.00it/s]
#                    all         26         51      0.951      0.941      0.984      0.812
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     280/299      12.1G    0.02456   0.003501          0         73        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.22it/s]
#                    all         26         51       0.96      0.932      0.979      0.824
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     281/299      12.1G    0.02463   0.003477          0         75        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.31it/s]
#                    all         26         51      0.961      0.975      0.984       0.82
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     282/299      12.1G    0.02278   0.003479          0         56        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.06it/s]
#                    all         26         51      0.961      0.956      0.984      0.836
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     283/299      12.1G    0.02444   0.003296          0         68        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.32it/s]
#                    all         26         51      0.961      0.957      0.986      0.828
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     284/299      12.1G    0.02507   0.003468          0         56        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.28it/s]
#                    all         26         51      0.954       0.98      0.987      0.833
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     285/299      12.1G    0.02332   0.003496          0         61        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.28it/s]
#                    all         26         51      0.959      0.921      0.978      0.824
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     286/299      12.1G    0.02431   0.003487          0         68        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.27it/s]
#                    all         26         51      0.959       0.92      0.977      0.817
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     287/299      12.1G    0.02406   0.003652          0         60        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.28it/s]
#                    all         26         51       0.94      0.922      0.974      0.813
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     288/299      12.1G    0.02453   0.003787          0         83        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.18it/s]
#                    all         26         51       0.96      0.945      0.984      0.819
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     289/299      12.1G    0.02381   0.003662          0         83        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.29it/s]
#                    all         26         51      0.953       0.98      0.986      0.821
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     290/299      12.1G     0.0241   0.003938          0         68        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.28it/s]
#                    all         26         51      0.954       0.98      0.986      0.821
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     291/299      12.1G    0.02432   0.003635          0         66        640: 100% 15/15 [00:11<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.28it/s]
#                    all         26         51      0.938       0.98      0.985      0.814
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     292/299      12.1G    0.02314   0.003229          0         60        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.23it/s]
#                    all         26         51      0.961      0.972      0.985      0.821
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     293/299      12.1G    0.02377   0.003794          0         78        640: 100% 15/15 [00:11<00:00,  1.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.27it/s]
#                    all         26         51      0.961       0.96      0.981      0.826
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     294/299      12.1G    0.02366   0.003347          0         62        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.25it/s]
#                    all         26         51      0.961       0.96      0.981       0.82
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     295/299      12.1G    0.02308   0.003527          0         49        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.36it/s]
#                    all         26         51      0.957      0.961      0.983      0.828
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     296/299      12.1G    0.02484   0.003819          0         81        640: 100% 15/15 [00:11<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         26         51      0.957      0.961      0.984      0.824
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     297/299      12.1G    0.02506   0.003727          0         74        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.17it/s]
#                    all         26         51      0.958      0.961      0.984      0.828
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     298/299      12.1G    0.02439   0.003435          0         65        640: 100% 15/15 [00:11<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.24it/s]
#                    all         26         51      0.957      0.961      0.984      0.829
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     299/299      12.1G    0.02409   0.003567          0         89        640: 100% 15/15 [00:11<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.25it/s]
#                    all         26         51      0.957      0.961      0.986      0.832
#
# 300 epochs completed in 1.059 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 42.2MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 42.2MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# YOLOv5m summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.23it/s]
#                    all         26         51      0.961      0.956      0.984      0.836
# Results saved to runs/train/exp

# %%
#Сохраняем обученную модель на компьютер
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')

# %% [markdown]
# # Новый раздел
